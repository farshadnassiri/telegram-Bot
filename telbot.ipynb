# %%
import telebot

# %%
bot = telebot.TeleBot("8482831224:AAGpust7xLA6FilDyc5HOEbNZhAM6Nx7J0o", parse_mode="MARKDOWN")

@bot.message_handler(commands=["start", "help"])
def start(message):
    bot.send_message(message.chat.id, "Hello, how are you?")

@bot.message_handler(func=lambda message: True)
def echo_all(message):
    bot.reply_to(message, message.content_type)



bot.infinity_polling()
# Out:
# 2025-11-01 18:04:40,583 (__init__.py:1121 MainThread) ERROR - TeleBot: "Infinity polling: polling exited"
# 2025-11-01 18:04:40,584 (__init__.py:1123 MainThread) ERROR - TeleBot: "Break infinity polling"

# %%
group_chat_id = -5043983016
bot.send_message(group_chat_id, "Hello, how are you?")
